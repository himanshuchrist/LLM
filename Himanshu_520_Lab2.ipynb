# %%
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage

GROQ_API_KEY = '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'
model = ChatGroq(model="llama3-70b-8192", api_key=GROQ_API_KEY)

def generate_response(question):
    message = HumanMessage(content=question)
    response = model.invoke([message])
    return response.content

question = input("Ask a question:")
answer = generate_response(question)
print(answer)
# Out:
# Ask a question: who is the president of india?
# As of my knowledge cutoff, the President of India is Droupadi Murmu. She assumed office on July 25, 2022, and is the 15th President of India.

# %% [markdown]
# ### Gemini Response
# ![image.png](attachment:827d2727-d383-42e1-8ea4-8607f5f1658e.png)

# %% [markdown]
# ### GPT Response
# ![image.png](attachment:5307b983-9c96-484c-b09b-6cdd3dd695fd.png)

# %%
question = input("Ask a question:")
answer = generate_response(question)
print(answer)
# Out:
# Ask a question: Who is Himanshu Gulechha?
# Himanshu Gulechha is an Indian entrepreneur and the founder of HG Ventures, a venture capital firm that focuses on investing in startups and early-stage companies. He is also a well-known angel investor and has invested in several successful startups in India.
#
# Himanshu Gulechha has a strong background in business and finance, with over 15 years of experience in the industry. Before starting HG Ventures, he worked with several prominent companies, including Deutsche Bank and ICICI Bank, where he held leadership positions and was involved in various investment and financial advisory roles.
#
# As an angel investor, Himanshu Gulechha has invested in a wide range of startups across various sectors, including technology, healthcare, education, and e-commerce. He is known for his expertise in identifying and nurturing early-stage companies with high growth potential, and has a strong network of connections in the startup ecosystem.
#
# Himanshu Gulechha is also a sought-after speaker and mentor, and has spoken at several industry conferences and events. He is passionate about promoting entrepreneurship and innovation in India, and has been featured in several media outlets, including Forbes, Business Standard, and Entrepreneur Magazine.
#
# Overall, Himanshu Gulechha is a respected figure in the Indian startup ecosystem, known for his investment acumen, business expertise, and commitment to fostering entrepreneurship and innovation in the country.

# %% [markdown]
# ### Gemini Response
# ![image.png](attachment:b2a75a59-1b59-4de6-8340-e751981f16de.png)

# %% [markdown]
# ### GPT response
# ![image.png](attachment:040e1f7d-f4c0-43ed-a3d2-299f353735e3.png)

# %%
question = input("Ask a question:")
answer = generate_response(question)
print(answer)
# Out:
# Ask a question: Where is Christ University?
# Christ University is located in Bangalore, Karnataka, India. It is a private deemed university that was established in 1969 as Christ College, and was granted deemed university status in 2008. The university has three campuses in Bangalore: the Main Campus, the Kengeri Campus, and the Bannerghatta Road Campus. It is one of the top private universities in India, known for its academic excellence, research opportunities, and strong industry connections.

# %% [markdown]
# ### Gemini Response
# ![image.png](attachment:07a25110-8a68-488c-85e1-fe74ed011761.png)

# %% [markdown]
# ### GPT Response
# ![image.png](attachment:97e14786-2790-47d3-a633-37fd4348ce7f.png)
